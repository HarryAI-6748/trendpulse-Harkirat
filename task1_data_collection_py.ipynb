# %% [markdown]
# <a href="https://colab.research.google.com/github/HarryAI-6748/trendpulse-Harkirat/blob/main/task1_data_collection_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the required libraries

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# Defining the URL - Free  REST API

# %%
url = "https://restcountries.com/v3.1/all"

# %% [markdown]
# Listing out the total number of possible parameters

# %%
params = {"fields": "name,population,region,area,flags,capital,currencies,languages,borders,tld,unMember,independent,demonyms,landlocked,subregion,continents"}
params['fields']
# Out:
# 'name,population,region,area,flags,capital,currencies,languages,borders,tld,unMember,independent,demonyms,landlocked,subregion,continents'

# %% [markdown]
# Fetching the data from URL using requests library and trying to parse the fetched data into a json file, but i can only fetch 10 parameters at a time

# %%
url = "https://restcountries.com/v3.1/all"
params = {"fields": "name,population,region,area,flags,capital,currencies,languages,borders,tld,unMember,independent,demonyms,landlocked,subregion,continents"}

response = requests.get(url, params)
count_data = response.json()
count_data
# Out:
# {'message': "'fields' query not specified or you're requesting more than 10 fields",
#  'status': 400}

# %% [markdown]
# Converting the fetched json into data frame with first 10 parameters

# %%
url = "https://restcountries.com/v3.1/all"
params = {"fields": "name,population,region,area,flags,capital,currencies,languages,borders,tld"}
response = requests.get(url, params)
count_data = response.json()
df = pd.DataFrame(count_data)
df
# Out:
#                                                  flags  \
# 0    {'png': 'https://flagcdn.com/w320/ci.png', 'sv...
# 1    {'png': 'https://flagcdn.com/w320/it.png', 'sv...
# 2    {'png': 'https://flagcdn.com/w320/kg.png', 'sv...
# 3    {'png': 'https://flagcdn.com/w320/pg.png', 'sv...
# 4    {'png': 'https://flagcdn.com/w320/fj.png', 'sv...
# ..                                                 ...
# 245  {'png': 'https://flagcdn.com/w320/sg.png', 'sv...
# 246  {'png': 'https://flagcdn.com/w320/cr.png', 'sv...
# 247  {'png': 'https://flagcdn.com/w320/rs.png', 'sv...
# 248  {'png': 'https://flagcdn.com/w320/pl.png', 'sv...
# 249  {'png': 'https://flagcdn.com/w320/jo.png', 'sv...
#
#                                                   name  \
# 0    {'common': 'Ivory Coast', 'official': 'Republi...
# 1    {'common': 'Italy', 'official': 'Italian Repub...
# 2    {'common': 'Kyrgyzstan', 'official': 'Kyrgyz R...
# 3    {'common': 'Papua New Guinea', 'official': 'In...
# ...

# %% [markdown]
# Converting the fetched json into data frame with remaining parameters

# %%
url = "https://restcountries.com/v3.1/all"
params = {"fields": "unMember,independent,demonyms,landlocked,subregion,continents"}
response = requests.get(url, params)
count_data = response.json()
df = pd.DataFrame(count_data)
df
# Out:
#                                               demonyms  independent  unMember  \
# 0    {'eng': {'f': 'Ivorian', 'm': 'Ivorian'}, 'fra...         True      True
# 1    {'eng': {'f': 'Italian', 'm': 'Italian'}, 'fra...         True      True
# 2    {'eng': {'f': 'Kirghiz', 'm': 'Kirghiz'}, 'fra...         True      True
# 3    {'eng': {'f': 'Papua New Guinean', 'm': 'Papua...         True      True
# 4    {'eng': {'f': 'Fijian', 'm': 'Fijian'}, 'fra':...         True      True
# ..                                                 ...          ...       ...
# 245  {'eng': {'f': 'Singaporean', 'm': 'Singaporean...         True      True
# 246  {'eng': {'f': 'Costa Rican', 'm': 'Costa Rican...         True      True
# 247  {'eng': {'f': 'Serbian', 'm': 'Serbian'}, 'fra...         True      True
# 248  {'eng': {'f': 'Polish', 'm': 'Polish'}, 'fra':...         True      True
# 249  {'eng': {'f': 'Jordanian', 'm': 'Jordanian'}, ...         True      True
#
# ...

# %% [markdown]
# Upon inspection of all parameters,a data frame with selected parameters is made

# %%
url = "https://restcountries.com/v3.1/all"
params = {"fields": "name,population,region,area,languages,borders,unMember,independent,subregion,continents"}

response = requests.get(url, params)
count_data = response.json()
df = pd.DataFrame(count_data)

# %% [markdown]
# Checking the data frame data using df.info() method. It provides a concise, high-level summary of a DataFrame’s structure and metadata. It is primarily being used  for exploratory data analysis (EDA) to quickly assess data quality, such as identifying missing values and ensuring correct data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         250 non-null    object
#  1   languages    250 non-null    object
#  2   independent  250 non-null    bool
#  3   unMember     250 non-null    bool
#  4   region       250 non-null    object
#  5   subregion    250 non-null    object
#  6   borders      250 non-null    object
#  7   area         250 non-null    float64
#  8   population   250 non-null    int64
#  9   continents   250 non-null    object
# dtypes: bool(2), float64(1), int64(1), object(6)
# memory usage: 16.2+ KB

# %% [markdown]
# Using df.describe() method to generate a statistical summary of a DataFrame's  numerical columns. It provides a quick overview of the data's central tendency, dispersion, and distribution shape.

# %%
df.describe()
# Out:
#                area    population
# count  2.500000e+02  2.500000e+02
# mean   6.010389e+05  3.207798e+07
# std    1.912575e+06  1.319655e+08
# min    4.900000e-01  0.000000e+00
# 25%    1.194250e+03  2.233542e+05
# 50%    6.492950e+04  5.279123e+06
# 75%    3.841505e+05  2.037166e+07
# max    1.709825e+07  1.417492e+09

# %% [markdown]
# Using df.describe() method to generate a statistical summary of a DataFrame's all columns

# %%
df.describe(include = 'all')
# Out:
#                                                      name           languages  \
# count                                                 250                 250
# unique                                                250                 142
# top     {'common': 'Ivory Coast', 'official': 'Republi...  {'eng': 'English'}
# freq                                                    1                  39
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
# ...

# %% [markdown]
# Using df.head() to have a quick visual inspection of the dataset to verify data loading, check column names, and understand the general structure without displaying the entire dataset

# %%
df.head()
# Out:
#                                                 name  \
# 0  {'common': 'Ivory Coast', 'official': 'Republi...
# 1  {'common': 'Italy', 'official': 'Italian Repub...
# 2  {'common': 'Kyrgyzstan', 'official': 'Kyrgyz R...
# 3  {'common': 'Papua New Guinea', 'official': 'In...
# 4  {'common': 'Fiji', 'official': 'Republic of Fi...
#
#                                            languages  independent  unMember  \
# 0                                  {'fra': 'French'}         True      True
# 1               {'ita': 'Italian', 'cat': 'Catalan'}         True      True
# 2                {'kir': 'Kyrgyz', 'rus': 'Russian'}         True      True
# 3  {'eng': 'English', 'hmo': 'Hiri Motu', 'tpi': ...         True      True
# 4  {'eng': 'English', 'fij': 'Fijian', 'hif': 'Fi...         True      True
#
#     region        subregion                         borders      area  \
# 0   Africa   Western Africa       [BFA, GHA, GIN, LBR, MLI]  322463.0
# ...
