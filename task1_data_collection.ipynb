# %% [markdown]
# <a href="https://colab.research.google.com/github/HarryAI-6748/trendpulse-Harkirat/blob/main/task1_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the required libraries

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# Fetching the ID as a json file

# %%
api_url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
api_url_2 = 'https://hacker-news.firebaseio.com/v0/item/{id}.json'
stories = {}

data = requests.get(url = api_url, headers = {"User-Agent": "TrendPulse/1.0"})
ids = data.json()

# %% [markdown]
# Fetching individual story per ID and defining categories as per their title

# %%
stories = {}
Technology = ['AI', 'software', 'tech', 'code', 'computer', 'data', 'cloud', 'API', 'GPU', 'LLM']
Worldnews = ['war', 'government', 'country', 'president', 'election', 'climate', 'attack', 'global']
Sports = ['NFL', 'NBA', 'FIFA', 'sport', 'game', 'team', 'player', 'league', 'championship']
Science = ['research', 'study', 'space', 'physics', 'biology', 'discovery', 'NASA', 'genome']
Entertainment = ['movie', 'film', 'music', 'Netflix', 'game', 'book', 'show', 'award', 'streaming']
for id in ids:
  response = requests.get(url = api_url_2.format(id = id), headers = {"User-Agent": "TrendPulse/1.0"})
  if response.status_code == 200:
    stories[id] = (requests.get(url = api_url_2.format(id = id), headers = {"User-Agent": "TrendPulse/1.0"})).json()
  else:
    print(response.status_code)
    continue
  #print(response.status_code)
#print(stories)

category = {}
collected_stories = {}
for story in stories.values():
  for y in Sports:
    if y in story['title'].split():
      category[story['id']] = 'sports'
  for z in Science:
    if z in story['title'].split():
      category[story['id']] = 'science'
  for w in Entertainment:
    if w in story['title'].split():
      category[story['id']] = 'entertainment'
  for t in Technology:
    if t  in story['title'].split():
      category[story['id']] = 'technology'
  for x in Worldnews:
    if x in story['title'].split():
      category[story['id']] = 'worldnews'

category
# Out:
# {47699814: 'technology',
#  47687273: 'technology',
#  47689174: 'technology',
#  47679121: 'technology',
#  47692661: 'technology',
#  47689319: 'technology',
#  47699090: 'technology',
#  47699105: 'technology',
#  47672295: 'technology',
#  47696210: 'technology',
#  47664836: 'technology',
#  47695647: 'technology',
#  47701013: 'technology',
#  47689550: 'technology',
#  47627217: 'science',
#  47673005: 'technology',
#  47672778: 'entertainment',
#  47677241: 'technology',
#  47696723: 'technology',
#  47661065: 'sports',
#  47696336: 'technology',
#  47655408: 'technology',
#  47664186: 'entertainment',
#  47699086: 'technology',
#  47667672: 'technology',
#  47684506: 'technology',
#  47673541: 'technology',
#  47648828: 'technology',
#  47652007: 'technology',
#  47688582: 'technology',
#  47640728: 'technology',
#  47655367: 'technology',
#  47656501: 'entertainment',
#  47662596: 'technology',
#  47662945: 'worldnews',
#  47665902: 'technology',
#  47682908: 'technology',
#  47694303: 'technology',
#  47700460: 'technology',
#  47690962: 'technology',
#  47682956: 'technology',
#  47690415: 'technology',
#  47665207: 'science',
#  47655466: 'technology',
#  47690049: 'entertainment',
#  47697525: 'technology',
#  47688712: 'technology',
#  47689135: 'technology',
#  47637757: 'technology',
#  47674950: 'technology',
#  47672792: 'technology',
#  47693799: 'worldnews',
#  47693990: 'technology',
#  47624645: 'technology',
#  47696600: 'technology',
#  47691409: 'science',
#  47672642: 'technology',
#  47674056: 'technology',
#  47683171: 'technology',
#  47682879: 'technology',
#  47640875: 'technology',
#  47682075: 'technology',
#  47694522: 'science',
#  47629485: 'science',
#  47645468: 'technology',
#  47639779: 'technology',
#  47670377: 'technology',
#  47641788: 'technology',
#  47620933: 'technology',
#  47682435: 'technology',
#  47673576: 'technology',
#  47627419: 'worldnews',
#  47672190: 'sports',
#  47630109: 'entertainment',
#  47686106: 'worldnews',
#  47625244: 'technology'}

# %% [markdown]
# Converting json file into data frames so that i can perform multiple operations on them

# %%
category_df = pd.DataFrame.from_dict(category, orient='index')
category_df.rename(columns={0: 'category'}, inplace=True)
category = category_df.reset_index()
category.sort_values(by=['index'], inplace=True)
category.rename(columns={'index': 'post_id'}, inplace=True)
category
# Out:
#      post_id    category
# 68  47620933  technology
# 53  47624645  technology
# 75  47625244  technology
# 14  47627217     science
# 71  47627419   worldnews
# ..       ...         ...
# 6   47699090  technology
# 7   47699105  technology
# 0   47699814  technology
# 38  47700460  technology
# 12  47701013  technology
#
# [76 rows x 2 columns]

# %%
stories_df = pd.DataFrame(stories).transpose().reset_index()
stories_df.head()
stories_df.transpose()
stories_df.reset_index().head(50)
stories_df.sort_values(by=['index'], inplace=True)
stories_df.rename(columns={'index': 'post_id'}, inplace=True)
stories_df
# Out:
#       post_id            by descendants        id  \
# 410  47619879        uticus          70  47619879
# 463  47620933         notem          36  47620933
# 254  47621133       benwerd           1  47621133
# 473  47621438     codingmoh          61  47621438
# 451  47621448     OhMeadhbh          30  47621448
# ..        ...           ...         ...       ...
# 127  47701013        doener           0  47701013
# 37   47701041        doener           4  47701041
# 3    47701100        nixass           7  47701100
# 5    47701233    sixhobbits          47  47701233
# 41   47701433  robtherobber           0  47701433
#
#                                                   kids score        time  \
# 410  [47621546, 47620214, 47620361, 47623695, 47620...    83  1775162417
# 463  [47622493, 47623131, 47622169, 47623243, 47622...    59  1775168484
# 254                                         [47695450]     9  1775169629
# 473  [47624129, 47622020, 47622428, 47622690, 47622...   153  1775171765
# 451  [47622081, 47624490, 47623480, 47622157, 47623...    79  1775171846
# ..                                                 ...   ...         ...
# 127                                                NaN     8  1775725283
# 37                                [47701228, 47701232]     8  1775725459
# 3                       [47701263, 47701271, 47701126]    23  1775725897
# 5    [47701555, 47701620, 47701550, 47701696, 47701...    61  1775726728
# 41                                                 NaN     5  1775728411
#
#                                                  title   type  \
# 410  U.S. is burning through Tomahawk cruise missil...  story
# 463  Memo: A language that remembers only the last ...  story
# 254                      Design for the Roller Coaster  story
# 473          Show HN: Made a little Artemis II tracker  story
# 451          A Few Good Magazines From the 70s and 80s  story
# ..                                                 ...    ...
# 127  Largest Dutch pension fund cuts ties with cont...  story
# 37   Nigel Farage wants to build a British ICE. Sta...  story
# 3    Creating the Futurescape for the Fifth Element...  story
# 5      Claude mixes up who said what and that's not OK  story
# 41                     America Has Lost the Arab World  story
#
#                                                    url  \
# 410  https://www.twz.com/news-features/u-s-is-burni...
# 463            https://danieltemkin.com/Esolangs/Memo/
# 254   https://pointc.co/design-for-the-roller-coaster/
# 473                    https://artemis-ii-tracker.com/
# 451                      https://www.bi6.us/CO/MG.HTML
# ..                                                 ...
# 127  https://nltimes.nl/2026/04/02/largest-dutch-pe...
# 37   https://www.thenerve.news/p/reform-deportation...
# 3    https://theasc.com/articles/fantastic-voyage-c...
# 5    https://dwyer.co.za/static/claude-mixes-up-who...
# 41   https://www.foreignaffairs.com/iran/america-ha...
#
#                                                   text
# 410                                                NaN
# 463                                                NaN
# 254                                                NaN
# 473  Made a little Artemis II tracker for anyone el...
# 451                                                NaN
# ..                                                 ...
# 127                                                NaN
# 37                                                 NaN
# 3                                                  NaN
# 5                                                  NaN
# 41                                                 NaN
#
# [500 rows x 11 columns]

# %%
un_df = pd.merge(category, stories_df, on='post_id', how='left')
un_df.rename(columns = {'descendants':'num_comments', 'by': 'author'}, inplace=True)
un = un_df.drop(columns=['id', 'kids', 'type', 'url', 'text'])
un['collected_at'] = pd.Timestamp.now()
Tot_Stories = un['post_id'].count()
un
# Out:
#      post_id    category           author num_comments score        time  \
# 0   47620933  technology            notem           36    59  1775168484
# 1   47624645  technology           franze          157   738  1775207734
# 2   47625244  technology  nickslaughter02          140   242  1775213931
# 3   47627217     science            romes          127   218  1775227348
# 4   47627419   worldnews        cmitsakis           12    47  1775228357
# ..       ...         ...              ...          ...   ...         ...
# 71  47699090  technology      Stratoscope            7    28  1775706738
# 72  47699105  technology          airobus            2     4  1775706987
# 73  47699814  technology         ankitg12            9    42  1775714455
# 74  47700460  technology    meander_water           63    49  1775720387
# 75  47701013  technology           doener            0     8  1775725283
#
#                                                 title  \
# 0   Memo: A language that remembers only the last ...
# 1    Show HN: Apfel – The free AI already on your Mac
# 2   Critics say EU risks ceding control of its tec...
# 3             Running out of disk space in production
# 4   The Axios supply chain attack used individuall...
# ..                                                ...
# 71  'There's a lot of desperation': older workers ...
# 72  Show HN: Image to Music AI – Turn Any Photo in...
# 73           Process Manager for Autonomous AI Agents
# 74  Ask HN: What are you building that's not AI re...
# 75  Largest Dutch pension fund cuts ties with cont...
#
#                  collected_at
# 0  2026-04-09 10:43:37.141318
# 1  2026-04-09 10:43:37.141318
# 2  2026-04-09 10:43:37.141318
# 3  2026-04-09 10:43:37.141318
# 4  2026-04-09 10:43:37.141318
# ..                        ...
# 71 2026-04-09 10:43:37.141318
# 72 2026-04-09 10:43:37.141318
# 73 2026-04-09 10:43:37.141318
# 74 2026-04-09 10:43:37.141318
# 75 2026-04-09 10:43:37.141318
#
# [76 rows x 8 columns]

# %% [markdown]
# Making a new folder called data

# %%
from pathlib import Path
Path("data").mkdir(exist_ok=True)

# %% [markdown]
# Converting the data frame to json file and saving in data folder

# %%
un.to_json("data/trends_20260409.json")
saved_path = "data/trends_20260409.json"
print(f"Collected {Tot_Stories} stories. Saved to {saved_path}")
